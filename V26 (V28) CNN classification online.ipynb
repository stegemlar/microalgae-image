# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from PIL import Image

# Path to the directory where the trained CNN model is saved
model_dir = "C:/Users/lsest/Python"
model_file = 'best_model.keras' 

model = load_model(os.path.join(model_dir, model_file))

# Directory containing the subfolders with images
# Requires 1 subfolder with images - name is irrelevant
main_image_dir = "C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1"

# Define datagen
gen = ImageDataGenerator(
    rescale=1/255.,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=0.4,  # Assuming this was intended to be a percentage; might need to be 40 for degrees
    zoom_range=0.4
)

# Prepare DataFrame to store results
class_percentages_list = []

# Iterate over each subfolder in the main image directory
for folder_name in os.listdir(main_image_dir):
    folder_path = os.path.join(main_image_dir, folder_name)
    print("Processing folder:", folder_path)

        # Create a generator to read images found in the directory
    images = gen.flow_from_directory(
            folder_path,
            target_size=(64, 64),  # Match the input size of your model
            color_mode='grayscale',  # Adjust if your model was trained on color images
            batch_size=1,
            class_mode=None,  # No classes provided
            shuffle=False
        )

    predictions = model.predict(images, steps=len(images))
    predicted_classes = np.argmax(predictions, axis=1)

    # Calculate class percentages
    unique, counts = np.unique(predicted_classes, return_counts=True)
    percentages = dict(zip(unique, counts * 100 / len(predicted_classes)))
    percentages['folder_name'] = folder_name
    class_percentages_list.append(percentages)
    print(f"Class percentages for {folder_name}: {percentages}")
    

# Create a DataFrame from the list
class_percentages_df = pd.DataFrame(class_percentages_list)

# Set folder_name as the first column
cols = ['folder_name'] + [col for col in class_percentages_df if col != 'folder_name']
class_percentages_df = class_percentages_df[cols]

# Save class percentages to a single CSV file
output_file = "C:/Users/lsest/Desktop/V28 CNN results.csv"
class_percentages_df.to_csv(output_file, index=False)
print("Results saved to", output_file)
# Out:
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_09-37-28.png
# Found 977 images belonging to 1 classes.
# 977/977 [==============================] - 12s 12ms/step
# Class percentages for _2024-02-29_09-37-28.png: {0: 4.81064483111566, 1: 11.87308085977482, 2: 7.778915046059366, 3: 20.67553735926305, 4: 54.8618219037871, 'folder_name': '_2024-02-29_09-37-28.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_10-37-30.png
# Found 902 images belonging to 1 classes.
# 902/902 [==============================] - 13s 14ms/step
# Class percentages for _2024-02-29_10-37-30.png: {0: 4.545454545454546, 1: 12.638580931263858, 2: 7.317073170731708, 3: 25.277161862527716, 4: 50.22172949002217, 'folder_name': '_2024-02-29_10-37-30.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_11-37-32.png
# Found 1068 images belonging to 1 classes.
# 1068/1068 [==============================] - 14s 14ms/step
# Class percentages for _2024-02-29_11-37-32.png: {0: 3.5580524344569286, 1: 11.142322097378278, 2: 7.022471910112359, 3: 22.65917602996255, 4: 55.61797752808989, 'folder_name': '_2024-02-29_11-37-32.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_12-37-32.png
# Found 1060 images belonging to 1 classes.
# 1060/1060 [==============================] - 14s 13ms/step
# Class percentages for _2024-02-29_12-37-32.png: {0: 3.490566037735849, 1: 13.20754716981132, 2: 7.169811320754717, 3: 23.67924528301887, 4: 52.45283018867924, 'folder_name': '_2024-02-29_12-37-32.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_13-37-34.png
# Found 996 images belonging to 1 classes.
# 996/996 [==============================] - 14s 14ms/step
# Class percentages for _2024-02-29_13-37-34.png: {0: 4.718875502008032, 1: 11.947791164658634, 2: 8.634538152610443, 3: 25.803212851405622, 4: 48.89558232931727, 'folder_name': '_2024-02-29_13-37-34.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_13-56-14.png
# Found 793 images belonging to 1 classes.
# 793/793 [==============================] - 12s 15ms/step
# Class percentages for _2024-02-29_13-56-14.png: {0: 1.7654476670870114, 1: 13.366960907944515, 2: 7.440100882723834, 3: 20.80706179066835, 4: 56.62042875157629, 'folder_name': '_2024-02-29_13-56-14.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_14-37-36.png
# Found 969 images belonging to 1 classes.
# 969/969 [==============================] - 14s 15ms/step
# Class percentages for _2024-02-29_14-37-36.png: {0: 3.8183694530443755, 1: 13.519091847265221, 2: 7.223942208462332, 3: 27.24458204334365, 4: 48.19401444788442, 'folder_name': '_2024-02-29_14-37-36.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_14-56-16.png
# Found 779 images belonging to 1 classes.
# 779/779 [==============================] - 11s 15ms/step
# Class percentages for _2024-02-29_14-56-16.png: {0: 3.337612323491656, 1: 12.836970474967908, 2: 7.702182284980744, 3: 28.241335044929397, 4: 47.881899871630296, 'folder_name': '_2024-02-29_14-56-16.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_15-56-18.png
# Found 770 images belonging to 1 classes.
# 770/770 [==============================] - 12s 15ms/step
# Class percentages for _2024-02-29_15-56-18.png: {0: 2.727272727272727, 1: 13.766233766233766, 2: 7.012987012987013, 3: 21.428571428571427, 4: 55.064935064935064, 'folder_name': '_2024-02-29_15-56-18.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_16-56-20.png
# Found 777 images belonging to 1 classes.
# 777/777 [==============================] - 12s 16ms/step
# Class percentages for _2024-02-29_16-56-20.png: {0: 5.148005148005148, 1: 10.682110682110682, 2: 9.652509652509652, 3: 17.63191763191763, 4: 56.88545688545688, 'folder_name': '_2024-02-29_16-56-20.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_17-56-22.png
# Found 776 images belonging to 1 classes.
# 776/776 [==============================] - 12s 16ms/step
# Class percentages for _2024-02-29_17-56-22.png: {0: 5.670103092783505, 1: 11.597938144329897, 2: 9.149484536082474, 3: 26.417525773195877, 4: 47.16494845360825, 'folder_name': '_2024-02-29_17-56-22.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_18-56-24.png
# Found 694 images belonging to 1 classes.
# 694/694 [==============================] - 10s 15ms/step
# Class percentages for _2024-02-29_18-56-24.png: {0: 6.340057636887608, 1: 9.94236311239193, 2: 10.806916426512968, 3: 15.706051873198847, 4: 57.20461095100865, 'folder_name': '_2024-02-29_18-56-24.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_19-56-26.png
# Found 727 images belonging to 1 classes.
# 727/727 [==============================] - 11s 15ms/step
# Class percentages for _2024-02-29_19-56-26.png: {0: 6.327372764786795, 1: 9.07840440165062, 2: 9.491059147180193, 3: 20.90784044016506, 4: 54.195323246217335, 'folder_name': '_2024-02-29_19-56-26.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_20-56-28.png
# Found 709 images belonging to 1 classes.
# 709/709 [==============================] - 11s 15ms/step
# Class percentages for _2024-02-29_20-56-28.png: {0: 7.898448519040903, 1: 12.411847672778562, 2: 10.437235543018335, 3: 20.310296191819464, 4: 48.94217207334274, 'folder_name': '_2024-02-29_20-56-28.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_21-56-30.png
# Found 653 images belonging to 1 classes.
# 653/653 [==============================] - 10s 15ms/step
# Class percentages for _2024-02-29_21-56-30.png: {0: 6.738131699846861, 1: 10.260336906584993, 2: 11.332312404287903, 3: 21.28637059724349, 4: 50.382848392036756, 'folder_name': '_2024-02-29_21-56-30.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_22-56-30.png
# Found 612 images belonging to 1 classes.
# 612/612 [==============================] - 10s 16ms/step
# Class percentages for _2024-02-29_22-56-30.png: {0: 8.006535947712418, 1: 10.620915032679738, 2: 13.562091503267974, 3: 22.058823529411764, 4: 45.751633986928105, 'folder_name': '_2024-02-29_22-56-30.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-02-29_23-56-34.png
# Found 644 images belonging to 1 classes.
# 644/644 [==============================] - 9s 14ms/step
# Class percentages for _2024-02-29_23-56-34.png: {0: 8.540372670807454, 1: 12.267080745341614, 2: 12.267080745341614, 3: 39.59627329192546, 4: 27.32919254658385, 'folder_name': '_2024-02-29_23-56-34.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_00-56-36.png
# Found 585 images belonging to 1 classes.
# 585/585 [==============================] - 8s 14ms/step
# Class percentages for _2024-03-01_00-56-36.png: {0: 7.17948717948718, 1: 11.965811965811966, 2: 12.478632478632479, 3: 26.495726495726494, 4: 41.88034188034188, 'folder_name': '_2024-03-01_00-56-36.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_01-56-36.png
# Found 590 images belonging to 1 classes.
# 590/590 [==============================] - 9s 15ms/step
# Class percentages for _2024-03-01_01-56-36.png: {0: 7.288135593220339, 1: 11.016949152542374, 2: 14.23728813559322, 3: 27.796610169491526, 4: 39.66101694915254, 'folder_name': '_2024-03-01_01-56-36.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_02-56-38.png
# Found 566 images belonging to 1 classes.
# 566/566 [==============================] - 8s 13ms/step
# Class percentages for _2024-03-01_02-56-38.png: {0: 9.187279151943462, 1: 10.777385159010601, 2: 11.837455830388693, 3: 30.742049469964666, 4: 37.45583038869258, 'folder_name': '_2024-03-01_02-56-38.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_03-56-40.png
# Found 524 images belonging to 1 classes.
# 524/524 [==============================] - 7s 14ms/step
# Class percentages for _2024-03-01_03-56-40.png: {0: 8.206106870229007, 1: 11.259541984732824, 2: 12.786259541984732, 3: 28.435114503816795, 4: 39.31297709923664, 'folder_name': '_2024-03-01_03-56-40.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_04-56-44.png
# Found 520 images belonging to 1 classes.
# 520/520 [==============================] - 8s 15ms/step
# Class percentages for _2024-03-01_04-56-44.png: {0: 7.3076923076923075, 1: 13.653846153846153, 2: 11.73076923076923, 3: 29.23076923076923, 4: 38.07692307692308, 'folder_name': '_2024-03-01_04-56-44.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_05-56-46.png
# Found 565 images belonging to 1 classes.
# 565/565 [==============================] - 9s 15ms/step
# Class percentages for _2024-03-01_05-56-46.png: {0: 6.725663716814159, 1: 10.442477876106194, 2: 10.973451327433628, 3: 27.787610619469028, 4: 44.07079646017699, 'folder_name': '_2024-03-01_05-56-46.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_06-56-46.png
# Found 542 images belonging to 1 classes.
# 542/542 [==============================] - 8s 15ms/step
# Class percentages for _2024-03-01_06-56-46.png: {0: 6.826568265682657, 1: 13.284132841328413, 2: 10.70110701107011, 3: 27.121771217712176, 4: 42.06642066420664, 'folder_name': '_2024-03-01_06-56-46.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_07-56-50.png
# Found 547 images belonging to 1 classes.
# 547/547 [==============================] - 8s 15ms/step
# Class percentages for _2024-03-01_07-56-50.png: {0: 6.03290676416819, 1: 10.786106032906764, 2: 9.689213893967093, 3: 26.508226691042047, 4: 46.983546617915906, 'folder_name': '_2024-03-01_07-56-50.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_09-33-10.png
# Found 820 images belonging to 1 classes.
# 820/820 [==============================] - 12s 15ms/step
# Class percentages for _2024-03-01_09-33-10.png: {0: 3.902439024390244, 1: 7.560975609756097, 2: 5.2439024390243905, 3: 21.21951219512195, 4: 62.073170731707314, 'folder_name': '_2024-03-01_09-33-10.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_10-33-08.png
# Found 899 images belonging to 1 classes.
# 899/899 [==============================] - 14s 15ms/step
# Class percentages for _2024-03-01_10-33-08.png: {0: 2.7808676307007785, 1: 8.008898776418242, 2: 6.896551724137931, 3: 26.807563959955505, 4: 55.506117908787544, 'folder_name': '_2024-03-01_10-33-08.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_11-33-10.png
# Found 806 images belonging to 1 classes.
# 806/806 [==============================] - 12s 15ms/step
# Class percentages for _2024-03-01_11-33-10.png: {0: 3.101736972704715, 1: 8.436724565756824, 2: 6.823821339950372, 3: 24.317617866004962, 4: 57.32009925558312, 'folder_name': '_2024-03-01_11-33-10.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_12-33-12.png
# Found 757 images belonging to 1 classes.
# 757/757 [==============================] - 11s 15ms/step
# Class percentages for _2024-03-01_12-33-12.png: {0: 3.3025099075297226, 1: 9.775429326287979, 2: 8.190224570673712, 3: 28.79788639365918, 4: 49.93394980184941, 'folder_name': '_2024-03-01_12-33-12.png'}
# Processing folder: C:/Users/lsest/OneDrive - Danmarks Tekniske Universitet/Experiments/V28 Online image Germination/Segmented_CNN/Part1\_2024-03-01_13-33-14.png
# Found 743 images belonging to 1 classes.
# 743/743 [==============================] - 11s 15ms/step
# Class percentages for _2024-03-01_13-33-14.png: {0: 3.499327052489906, 1: 10.767160161507402, 2: 6.864064602960969, 3: 25.841184387617766, 4: 53.02826379542396, 'folder_name': '_2024-03-01_13-33-14.png'}
# Results saved to C:/Users/lsest/Desktop/V28 CNN results.csv
